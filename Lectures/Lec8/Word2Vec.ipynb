# %% [markdown]
# # Getting started with Word2Vec in Gensim and making it work!
#
# The idea behind Word2Vec is pretty simple. We are making and assumption that you can tell the meaning of a word by the company it keeps. So if you have two words that have very similar neighbors (i.e. the usage context is about the same), then these words are probably quite similar in meaning or are at least highly related. For example, the words `shocked`,`appalled` and `astonished` are typically used in a similar context, so we can convert them to similar vectors to encapsulate their meaning.
#
# In this tutorial, we will learn how to use the Gensim implementation of Word2Vec. The training algorithms in this package were ported from the [original Word2Vec implementation by Google](https://arxiv.org/pdf/1301.3781.pdf) and extended with additional functionality.

# %% [markdown]
# ### Imports and logging
#
# First, we start with our imports and get logging established:

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ### Dataset
# Next, is our dataset. The secret to Word2Vec is lots and lots of text data. We will use data from the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset. This dataset has full user reviews of cars and hotels. I have specifically concatenated all of the hotel reviews into one big file which is about 97MB compressed and 229MB uncompressed. We will use the compressed file for this tutorial. Each line in this file represents a hotel review.
#
# While gensim’s word2vec tutorial says that you need to pass it a sequence of sentences as its input, you can pass it a whole review as a sentence (i.e. a much larger size of text), and it does not make much difference
#
# Let's see what this dataset is really about by printing the first line:

# %%
data_file="reviews_data.txt.gz"

with gzip.open ('reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %% [markdown]
# ### Read files into a list
# We can now read our dataset into a list so that we can pass it to the Word2Vec model. We are reading directly from the compressed file and lightly preprocessing the data using `gensim.utils.simple_preprocess (line)`. We tokenize (break the sentences down into ordered words), lowercase, etc and return back a list of tokens (words). Documentation of this pre-processing method can be found on the official [Gensim documentation site](https://radimrehurek.com/gensim/utils.html).

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10000==0):
                logging.info ("read {0} reviews".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list (read_input (data_file))
logging.info ("Done reading data file")
# Out:
# 2019-04-02 16:02:54,792 : INFO : reading file reviews_data.txt.gz...this may take a while
# 2019-04-02 16:02:54,794 : INFO : read 0 reviews
# 2019-04-02 16:02:56,843 : INFO : read 10000 reviews
# 2019-04-02 16:02:59,090 : INFO : read 20000 reviews
# 2019-04-02 16:03:01,593 : INFO : read 30000 reviews
# 2019-04-02 16:03:03,817 : INFO : read 40000 reviews
# 2019-04-02 16:03:06,386 : INFO : read 50000 reviews
# 2019-04-02 16:03:08,800 : INFO : read 60000 reviews
# 2019-04-02 16:03:10,828 : INFO : read 70000 reviews
# 2019-04-02 16:03:12,942 : INFO : read 80000 reviews
# 2019-04-02 16:03:14,949 : INFO : read 90000 reviews
# 2019-04-02 16:03:16,900 : INFO : read 100000 reviews
# 2019-04-02 16:03:18,908 : INFO : read 110000 reviews
# 2019-04-02 16:03:21,005 : INFO : read 120000 reviews
# 2019-04-02 16:03:23,123 : INFO : read 130000 reviews
# 2019-04-02 16:03:25,556 : INFO : read 140000 reviews
# 2019-04-02 16:03:27,718 : INFO : read 150000 reviews
# 2019-04-02 16:03:29,810 : INFO : read 160000 reviews
# 2019-04-02 16:03:31,812 : INFO : read 170000 reviews
# 2019-04-02 16:03:36,473 : INFO : read 180000 reviews
# 2019-04-02 16:03:38,658 : INFO : read 190000 reviews
# 2019-04-02 16:03:40,988 : INFO : read 200000 reviews
# 2019-04-02 16:03:43,124 : INFO : read 210000 reviews
# 2019-04-02 16:03:45,191 : INFO : read 220000 reviews
# 2019-04-02 16:03:47,042 : INFO : read 230000 reviews
# 2019-04-02 16:03:49,158 : INFO : read 240000 reviews
# 2019-04-02 16:03:51,252 : INFO : read 250000 reviews
# 2019-04-02 16:03:52,414 : INFO : Done reading data file

# %% [markdown]
# ## Training the Word2Vec model
#
# Training the model is fairly straightforward. You just instantiate Word2Vec and pass the reviews that we read in the previous step (the `documents`). So, we are essentially passing on a list of lists. Where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary. And by vocabulary, I mean a set of unique words.
#
# After building the vocabulary, we just need to call `train(...)` to start training the Word2Vec model. Training on the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset takes about 10 minutes so please be patient while running your code on this dataset.
#
# Behind the scenes we are actually training a simple neural network with a single hidden layer. But, we are actually not going to use the neural network after training. Instead, the goal is to learn the weights of the hidden layer. These weights are essentially the word vectors that we’re trying to learn.

# %%
model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10, sg=1)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2019-04-02 16:07:15,182 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-04-02 16:07:15,185 : INFO : collecting all words and their counts
# 2019-04-02 16:07:15,186 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-04-02 16:07:15,594 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2019-04-02 16:07:16,018 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2019-04-02 16:07:16,590 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2019-04-02 16:07:17,279 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2019-04-02 16:07:17,914 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2019-04-02 16:07:18,463 : INFO : PROGRESS: at sentence #60000, processed 11013726 words, keeping 76786 word types
# 2019-04-02 16:07:18,935 : INFO : PROGRESS: at sentence #70000, processed 12637528 words, keeping 83199 word types
# 2019-04-02 16:07:19,346 : INFO : PROGRESS: at sentence #80000, processed 14099754 words, keeping 88459 word types
# 2019-04-02 16:07:19,816 : INFO : PROGRESS: at sentence #90000, processed 15662152 words, keeping 93357 word types
# 2019-04-02 16:07:20,342 : INFO : PROGRESS: at sentence #100000, processed 17164490 words, keeping 97886 word types
# 2019-04-02 16:07:20,782 : INFO : PROGRESS: at sentence #110000, processed 18652295 words, keeping 102132 word types
# 2019-04-02 16:07:21,256 : INFO : PROGRESS: at sentence #120000, processed 20152532 words, keeping 105923 word types
# 2019-04-02 16:07:21,834 : INFO : PROGRESS: at sentence #130000, processed 21684333 words, keeping 110104 word types
# 2019-04-02 16:07:22,356 : INFO : PROGRESS: at sentence #140000, processed 23330209 words, keeping 114108 word types
# 2019-04-02 16:07:22,917 : INFO : PROGRESS: at sentence #150000, processed 24838757 words, keeping 118174 word types
# 2019-04-02 16:07:23,399 : INFO : PROGRESS: at sentence #160000, processed 26390913 words, keeping 118670 word types
# 2019-04-02 16:07:23,971 : INFO : PROGRESS: at sentence #170000, processed 27913919 words, keeping 123356 word types
# 2019-04-02 16:07:24,475 : INFO : PROGRESS: at sentence #180000, processed 29535615 words, keeping 126748 word types
# 2019-04-02 16:07:25,014 : INFO : PROGRESS: at sentence #190000, processed 31096462 words, keeping 129847 word types
# 2019-04-02 16:07:25,622 : INFO : PROGRESS: at sentence #200000, processed 32805274 words, keeping 133255 word types
# 2019-04-02 16:07:26,132 : INFO : PROGRESS: at sentence #210000, processed 34434201 words, keeping 136364 word types
# 2019-04-02 16:07:26,656 : INFO : PROGRESS: at sentence #220000, processed 36083485 words, keeping 139418 word types
# 2019-04-02 16:07:27,200 : INFO : PROGRESS: at sentence #230000, processed 37571765 words, keeping 142399 word types
# 2019-04-02 16:07:27,704 : INFO : PROGRESS: at sentence #240000, processed 39138193 words, keeping 145232 word types
# 2019-04-02 16:07:28,183 : INFO : PROGRESS: at sentence #250000, processed 40695052 words, keeping 147966 word types
# 2019-04-02 16:07:28,438 : INFO : collected 150059 word types from a corpus of 41519358 raw words and 255404 sentences
# 2019-04-02 16:07:28,439 : INFO : Loading a fresh vocabulary
# 2019-04-02 16:07:34,802 : INFO : effective_min_count=2 retains 70537 unique words (47% of original 150059, drops 79522)
# 2019-04-02 16:07:34,806 : INFO : effective_min_count=2 leaves 41439836 word corpus (99% of original 41519358, drops 79522)
# 2019-04-02 16:07:35,020 : INFO : deleting the raw counts dictionary of 150059 items
# 2019-04-02 16:07:35,030 : INFO : sample=0.001 downsamples 55 most-common words
# 2019-04-02 16:07:35,032 : INFO : downsampling leaves estimated 30349251 word corpus (73.2% of prior 41439836)
# 2019-04-02 16:07:35,254 : INFO : estimated required memory for 70537 words and 150 dimensions: 119912900 bytes
# 2019-04-02 16:07:35,255 : INFO : resetting layer weights
# 2019-04-02 16:07:36,147 : INFO : training model with 10 workers on 70537 vocabulary and 150 features, using sg=1 hs=0 sample=0.001 negative=5 window=10
# 2019-04-02 16:07:37,192 : INFO : EPOCH 1 - PROGRESS: at 0.89% examples, 286712 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:38,197 : INFO : EPOCH 1 - PROGRESS: at 2.15% examples, 332778 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:39,264 : INFO : EPOCH 1 - PROGRESS: at 3.51% examples, 350824 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:40,288 : INFO : EPOCH 1 - PROGRESS: at 4.73% examples, 353095 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:41,296 : INFO : EPOCH 1 - PROGRESS: at 5.73% examples, 343811 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:07:42,353 : INFO : EPOCH 1 - PROGRESS: at 6.81% examples, 338516 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:07:43,353 : INFO : EPOCH 1 - PROGRESS: at 7.82% examples, 336488 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:44,393 : INFO : EPOCH 1 - PROGRESS: at 8.84% examples, 333259 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:07:45,416 : INFO : EPOCH 1 - PROGRESS: at 9.69% examples, 328230 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:07:46,418 : INFO : EPOCH 1 - PROGRESS: at 10.51% examples, 327824 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:07:47,440 : INFO : EPOCH 1 - PROGRESS: at 11.38% examples, 326082 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:48,510 : INFO : EPOCH 1 - PROGRESS: at 12.25% examples, 326892 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:49,543 : INFO : EPOCH 1 - PROGRESS: at 13.38% examples, 328593 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:50,575 : INFO : EPOCH 1 - PROGRESS: at 14.31% examples, 328533 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:07:51,624 : INFO : EPOCH 1 - PROGRESS: at 15.16% examples, 325397 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:07:52,644 : INFO : EPOCH 1 - PROGRESS: at 16.13% examples, 325011 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:53,646 : INFO : EPOCH 1 - PROGRESS: at 17.05% examples, 325280 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:54,674 : INFO : EPOCH 1 - PROGRESS: at 17.83% examples, 323226 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:55,712 : INFO : EPOCH 1 - PROGRESS: at 18.73% examples, 322547 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:07:56,719 : INFO : EPOCH 1 - PROGRESS: at 19.58% examples, 323119 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:57,743 : INFO : EPOCH 1 - PROGRESS: at 20.49% examples, 324370 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:58,756 : INFO : EPOCH 1 - PROGRESS: at 21.67% examples, 324984 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:07:59,757 : INFO : EPOCH 1 - PROGRESS: at 22.58% examples, 326150 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:00,791 : INFO : EPOCH 1 - PROGRESS: at 23.43% examples, 325887 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:01,818 : INFO : EPOCH 1 - PROGRESS: at 24.36% examples, 326842 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:02,819 : INFO : EPOCH 1 - PROGRESS: at 25.55% examples, 327522 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:03,835 : INFO : EPOCH 1 - PROGRESS: at 26.83% examples, 328319 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:04,883 : INFO : EPOCH 1 - PROGRESS: at 28.23% examples, 328917 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:05,892 : INFO : EPOCH 1 - PROGRESS: at 29.48% examples, 329836 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:06,920 : INFO : EPOCH 1 - PROGRESS: at 30.73% examples, 330329 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:07,955 : INFO : EPOCH 1 - PROGRESS: at 31.91% examples, 328880 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:08:08,968 : INFO : EPOCH 1 - PROGRESS: at 32.80% examples, 326825 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:10,060 : INFO : EPOCH 1 - PROGRESS: at 33.58% examples, 323105 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:11,081 : INFO : EPOCH 1 - PROGRESS: at 34.55% examples, 321981 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:08:12,084 : INFO : EPOCH 1 - PROGRESS: at 35.56% examples, 321233 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:13,090 : INFO : EPOCH 1 - PROGRESS: at 36.66% examples, 320680 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:14,090 : INFO : EPOCH 1 - PROGRESS: at 37.71% examples, 320392 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:15,107 : INFO : EPOCH 1 - PROGRESS: at 38.81% examples, 319783 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:16,118 : INFO : EPOCH 1 - PROGRESS: at 39.89% examples, 319461 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:17,131 : INFO : EPOCH 1 - PROGRESS: at 41.03% examples, 319129 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:18,180 : INFO : EPOCH 1 - PROGRESS: at 42.30% examples, 319205 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:19,190 : INFO : EPOCH 1 - PROGRESS: at 43.36% examples, 318749 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:20,210 : INFO : EPOCH 1 - PROGRESS: at 44.52% examples, 318264 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:21,215 : INFO : EPOCH 1 - PROGRESS: at 45.72% examples, 318514 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:08:22,230 : INFO : EPOCH 1 - PROGRESS: at 46.81% examples, 318515 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:23,243 : INFO : EPOCH 1 - PROGRESS: at 47.91% examples, 318562 words/s, in_qsize 20, out_qsize 1
# 2019-04-02 16:08:24,265 : INFO : EPOCH 1 - PROGRESS: at 49.18% examples, 319149 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:25,306 : INFO : EPOCH 1 - PROGRESS: at 50.35% examples, 319253 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:26,319 : INFO : EPOCH 1 - PROGRESS: at 51.56% examples, 319823 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:27,322 : INFO : EPOCH 1 - PROGRESS: at 52.62% examples, 320014 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:28,341 : INFO : EPOCH 1 - PROGRESS: at 53.62% examples, 319968 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:29,408 : INFO : EPOCH 1 - PROGRESS: at 54.84% examples, 320368 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:30,416 : INFO : EPOCH 1 - PROGRESS: at 56.18% examples, 320937 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:31,417 : INFO : EPOCH 1 - PROGRESS: at 57.35% examples, 321146 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:32,436 : INFO : EPOCH 1 - PROGRESS: at 58.39% examples, 320972 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:33,506 : INFO : EPOCH 1 - PROGRESS: at 59.44% examples, 320146 words/s, in_qsize 19, out_qsize 1
# 2019-04-02 16:08:34,510 : INFO : EPOCH 1 - PROGRESS: at 60.65% examples, 320747 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:35,518 : INFO : EPOCH 1 - PROGRESS: at 61.71% examples, 320544 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:36,544 : INFO : EPOCH 1 - PROGRESS: at 62.92% examples, 320846 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:37,559 : INFO : EPOCH 1 - PROGRESS: at 64.23% examples, 320950 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:38,580 : INFO : EPOCH 1 - PROGRESS: at 65.28% examples, 320538 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:39,615 : INFO : EPOCH 1 - PROGRESS: at 66.26% examples, 320272 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:40,654 : INFO : EPOCH 1 - PROGRESS: at 67.38% examples, 320108 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:41,664 : INFO : EPOCH 1 - PROGRESS: at 68.55% examples, 320556 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:42,673 : INFO : EPOCH 1 - PROGRESS: at 69.64% examples, 320664 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:43,674 : INFO : EPOCH 1 - PROGRESS: at 70.70% examples, 320822 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:44,686 : INFO : EPOCH 1 - PROGRESS: at 71.79% examples, 321038 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:45,712 : INFO : EPOCH 1 - PROGRESS: at 72.92% examples, 320752 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:46,720 : INFO : EPOCH 1 - PROGRESS: at 74.02% examples, 320455 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:08:47,729 : INFO : EPOCH 1 - PROGRESS: at 75.09% examples, 320661 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:08:48,737 : INFO : EPOCH 1 - PROGRESS: at 76.11% examples, 320783 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:49,745 : INFO : EPOCH 1 - PROGRESS: at 77.15% examples, 320886 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:50,758 : INFO : EPOCH 1 - PROGRESS: at 78.21% examples, 321058 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:51,818 : INFO : EPOCH 1 - PROGRESS: at 79.25% examples, 320655 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:08:52,832 : INFO : EPOCH 1 - PROGRESS: at 80.32% examples, 320751 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:53,865 : INFO : EPOCH 1 - PROGRESS: at 81.32% examples, 320554 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:54,883 : INFO : EPOCH 1 - PROGRESS: at 82.48% examples, 320710 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:08:55,895 : INFO : EPOCH 1 - PROGRESS: at 83.54% examples, 320612 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:56,911 : INFO : EPOCH 1 - PROGRESS: at 84.56% examples, 320756 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:57,928 : INFO : EPOCH 1 - PROGRESS: at 85.71% examples, 320982 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:08:58,935 : INFO : EPOCH 1 - PROGRESS: at 86.95% examples, 321255 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:08:59,954 : INFO : EPOCH 1 - PROGRESS: at 88.14% examples, 321298 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:00,974 : INFO : EPOCH 1 - PROGRESS: at 89.40% examples, 321620 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:09:02,039 : INFO : EPOCH 1 - PROGRESS: at 90.68% examples, 321851 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:03,095 : INFO : EPOCH 1 - PROGRESS: at 91.94% examples, 322091 words/s, in_qsize 20, out_qsize 1
# 2019-04-02 16:09:04,145 : INFO : EPOCH 1 - PROGRESS: at 92.89% examples, 321520 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:05,145 : INFO : EPOCH 1 - PROGRESS: at 94.05% examples, 321720 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:06,149 : INFO : EPOCH 1 - PROGRESS: at 95.24% examples, 321900 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:07,168 : INFO : EPOCH 1 - PROGRESS: at 96.35% examples, 321959 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:08,171 : INFO : EPOCH 1 - PROGRESS: at 97.53% examples, 322107 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:09,174 : INFO : EPOCH 1 - PROGRESS: at 98.69% examples, 322284 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:10,099 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-04-02 16:09:10,106 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-04-02 16:09:10,118 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-02 16:09:10,124 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-02 16:09:10,125 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-02 16:09:10,149 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-02 16:09:10,161 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-02 16:09:10,182 : INFO : EPOCH 1 - PROGRESS: at 99.95% examples, 322627 words/s, in_qsize 2, out_qsize 1
# 2019-04-02 16:09:10,183 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-02 16:09:10,196 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-02 16:09:10,201 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-02 16:09:10,202 : INFO : EPOCH - 1 : training on 41519358 raw words (30349467 effective words) took 94.0s, 322715 effective words/s
# 2019-04-02 16:09:11,233 : INFO : EPOCH 2 - PROGRESS: at 0.87% examples, 282848 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:12,242 : INFO : EPOCH 2 - PROGRESS: at 1.88% examples, 291836 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:09:13,285 : INFO : EPOCH 2 - PROGRESS: at 2.98% examples, 300621 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:14,299 : INFO : EPOCH 2 - PROGRESS: at 4.04% examples, 305485 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:15,363 : INFO : EPOCH 2 - PROGRESS: at 5.15% examples, 308207 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:09:16,401 : INFO : EPOCH 2 - PROGRESS: at 6.30% examples, 314521 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:17,410 : INFO : EPOCH 2 - PROGRESS: at 7.33% examples, 314391 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:09:18,447 : INFO : EPOCH 2 - PROGRESS: at 8.41% examples, 315827 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:09:19,484 : INFO : EPOCH 2 - PROGRESS: at 9.45% examples, 319331 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:20,543 : INFO : EPOCH 2 - PROGRESS: at 10.38% examples, 321423 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:21,558 : INFO : EPOCH 2 - PROGRESS: at 11.36% examples, 323696 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:22,569 : INFO : EPOCH 2 - PROGRESS: at 12.21% examples, 325667 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:23,573 : INFO : EPOCH 2 - PROGRESS: at 13.29% examples, 327155 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:24,577 : INFO : EPOCH 2 - PROGRESS: at 14.30% examples, 329252 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:25,593 : INFO : EPOCH 2 - PROGRESS: at 15.38% examples, 330990 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:26,627 : INFO : EPOCH 2 - PROGRESS: at 16.27% examples, 329490 words/s, in_qsize 17, out_qsize 2
# 2019-04-02 16:09:27,655 : INFO : EPOCH 2 - PROGRESS: at 17.23% examples, 330359 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:09:28,669 : INFO : EPOCH 2 - PROGRESS: at 18.17% examples, 330895 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:29,677 : INFO : EPOCH 2 - PROGRESS: at 19.13% examples, 332138 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:30,694 : INFO : EPOCH 2 - PROGRESS: at 20.00% examples, 332405 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:09:31,701 : INFO : EPOCH 2 - PROGRESS: at 20.86% examples, 332923 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:32,716 : INFO : EPOCH 2 - PROGRESS: at 22.07% examples, 333076 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:33,730 : INFO : EPOCH 2 - PROGRESS: at 22.99% examples, 333740 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:34,756 : INFO : EPOCH 2 - PROGRESS: at 23.88% examples, 334436 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:09:35,777 : INFO : EPOCH 2 - PROGRESS: at 24.81% examples, 334034 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:36,844 : INFO : EPOCH 2 - PROGRESS: at 26.00% examples, 332849 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:37,851 : INFO : EPOCH 2 - PROGRESS: at 27.32% examples, 333260 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:38,852 : INFO : EPOCH 2 - PROGRESS: at 28.56% examples, 333471 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:39,864 : INFO : EPOCH 2 - PROGRESS: at 29.83% examples, 333970 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:40,894 : INFO : EPOCH 2 - PROGRESS: at 31.01% examples, 333646 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:41,898 : INFO : EPOCH 2 - PROGRESS: at 32.35% examples, 334409 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:42,910 : INFO : EPOCH 2 - PROGRESS: at 33.58% examples, 335081 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:09:43,978 : INFO : EPOCH 2 - PROGRESS: at 34.81% examples, 335641 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:45,016 : INFO : EPOCH 2 - PROGRESS: at 36.12% examples, 336006 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:09:46,025 : INFO : EPOCH 2 - PROGRESS: at 37.35% examples, 336595 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:47,050 : INFO : EPOCH 2 - PROGRESS: at 38.73% examples, 337365 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:48,090 : INFO : EPOCH 2 - PROGRESS: at 39.92% examples, 337240 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:49,108 : INFO : EPOCH 2 - PROGRESS: at 41.19% examples, 337139 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:50,109 : INFO : EPOCH 2 - PROGRESS: at 42.50% examples, 337864 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:51,141 : INFO : EPOCH 2 - PROGRESS: at 43.78% examples, 337989 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:52,142 : INFO : EPOCH 2 - PROGRESS: at 45.17% examples, 338663 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:53,155 : INFO : EPOCH 2 - PROGRESS: at 46.40% examples, 338910 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:54,164 : INFO : EPOCH 2 - PROGRESS: at 47.45% examples, 338320 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:55,167 : INFO : EPOCH 2 - PROGRESS: at 48.37% examples, 336553 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:56,168 : INFO : EPOCH 2 - PROGRESS: at 49.51% examples, 336116 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:57,203 : INFO : EPOCH 2 - PROGRESS: at 50.64% examples, 335763 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:58,208 : INFO : EPOCH 2 - PROGRESS: at 51.77% examples, 335599 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:09:59,228 : INFO : EPOCH 2 - PROGRESS: at 52.73% examples, 334780 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:00,248 : INFO : EPOCH 2 - PROGRESS: at 53.85% examples, 335002 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:01,273 : INFO : EPOCH 2 - PROGRESS: at 54.94% examples, 334533 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:10:02,280 : INFO : EPOCH 2 - PROGRESS: at 56.23% examples, 334724 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:10:03,348 : INFO : EPOCH 2 - PROGRESS: at 57.44% examples, 334530 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:04,357 : INFO : EPOCH 2 - PROGRESS: at 58.62% examples, 334813 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:05,371 : INFO : EPOCH 2 - PROGRESS: at 59.82% examples, 334827 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:06,394 : INFO : EPOCH 2 - PROGRESS: at 60.97% examples, 334678 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:07,408 : INFO : EPOCH 2 - PROGRESS: at 61.96% examples, 333932 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:08,414 : INFO : EPOCH 2 - PROGRESS: at 62.90% examples, 332742 words/s, in_qsize 17, out_qsize 2
# 2019-04-02 16:10:09,424 : INFO : EPOCH 2 - PROGRESS: at 64.05% examples, 331933 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:10,443 : INFO : EPOCH 2 - PROGRESS: at 65.09% examples, 331103 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:10:11,454 : INFO : EPOCH 2 - PROGRESS: at 66.11% examples, 331036 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:12,473 : INFO : EPOCH 2 - PROGRESS: at 67.21% examples, 330780 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:13,510 : INFO : EPOCH 2 - PROGRESS: at 68.38% examples, 330830 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:14,522 : INFO : EPOCH 2 - PROGRESS: at 69.43% examples, 330637 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:10:15,582 : INFO : EPOCH 2 - PROGRESS: at 70.46% examples, 330247 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:10:16,592 : INFO : EPOCH 2 - PROGRESS: at 71.57% examples, 330233 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:17,608 : INFO : EPOCH 2 - PROGRESS: at 72.74% examples, 330389 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:18,617 : INFO : EPOCH 2 - PROGRESS: at 74.07% examples, 330776 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:19,630 : INFO : EPOCH 2 - PROGRESS: at 75.16% examples, 331022 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:20,642 : INFO : EPOCH 2 - PROGRESS: at 76.30% examples, 331490 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:21,649 : INFO : EPOCH 2 - PROGRESS: at 77.46% examples, 331956 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:22,677 : INFO : EPOCH 2 - PROGRESS: at 78.58% examples, 332105 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:10:23,689 : INFO : EPOCH 2 - PROGRESS: at 79.72% examples, 332140 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:24,706 : INFO : EPOCH 2 - PROGRESS: at 80.85% examples, 332435 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:10:25,714 : INFO : EPOCH 2 - PROGRESS: at 81.92% examples, 332189 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:10:26,770 : INFO : EPOCH 2 - PROGRESS: at 82.82% examples, 331091 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:27,816 : INFO : EPOCH 2 - PROGRESS: at 83.86% examples, 330706 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:28,847 : INFO : EPOCH 2 - PROGRESS: at 84.85% examples, 330477 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:10:29,848 : INFO : EPOCH 2 - PROGRESS: at 85.92% examples, 330292 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:30,855 : INFO : EPOCH 2 - PROGRESS: at 87.11% examples, 330280 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:31,856 : INFO : EPOCH 2 - PROGRESS: at 88.37% examples, 330554 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:10:32,865 : INFO : EPOCH 2 - PROGRESS: at 89.66% examples, 330891 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:33,878 : INFO : EPOCH 2 - PROGRESS: at 90.91% examples, 331118 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:34,892 : INFO : EPOCH 2 - PROGRESS: at 92.19% examples, 331418 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:35,904 : INFO : EPOCH 2 - PROGRESS: at 93.38% examples, 331869 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:36,929 : INFO : EPOCH 2 - PROGRESS: at 94.62% examples, 332036 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:37,936 : INFO : EPOCH 2 - PROGRESS: at 95.85% examples, 332346 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:38,939 : INFO : EPOCH 2 - PROGRESS: at 97.09% examples, 332636 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:39,941 : INFO : EPOCH 2 - PROGRESS: at 98.28% examples, 332771 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:40,971 : INFO : EPOCH 2 - PROGRESS: at 99.53% examples, 332895 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:41,153 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-04-02 16:10:41,158 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-04-02 16:10:41,170 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-02 16:10:41,177 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-02 16:10:41,184 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-02 16:10:41,194 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-02 16:10:41,194 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-02 16:10:41,213 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-02 16:10:41,214 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-02 16:10:41,220 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-02 16:10:41,221 : INFO : EPOCH - 2 : training on 41519358 raw words (30347457 effective words) took 91.0s, 333448 effective words/s
# 2019-04-02 16:10:42,239 : INFO : EPOCH 3 - PROGRESS: at 1.06% examples, 345164 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:43,354 : INFO : EPOCH 3 - PROGRESS: at 2.28% examples, 340428 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:44,362 : INFO : EPOCH 3 - PROGRESS: at 3.51% examples, 348289 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:45,380 : INFO : EPOCH 3 - PROGRESS: at 4.73% examples, 351665 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:46,389 : INFO : EPOCH 3 - PROGRESS: at 5.94% examples, 355246 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:47,390 : INFO : EPOCH 3 - PROGRESS: at 7.12% examples, 355983 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:48,412 : INFO : EPOCH 3 - PROGRESS: at 8.23% examples, 355344 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:49,412 : INFO : EPOCH 3 - PROGRESS: at 9.33% examples, 355900 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:50,423 : INFO : EPOCH 3 - PROGRESS: at 10.21% examples, 355816 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:51,424 : INFO : EPOCH 3 - PROGRESS: at 11.21% examples, 356121 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:52,465 : INFO : EPOCH 3 - PROGRESS: at 12.15% examples, 355774 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:53,467 : INFO : EPOCH 3 - PROGRESS: at 13.26% examples, 356709 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:54,500 : INFO : EPOCH 3 - PROGRESS: at 14.32% examples, 357028 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:55,500 : INFO : EPOCH 3 - PROGRESS: at 15.38% examples, 356832 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:56,516 : INFO : EPOCH 3 - PROGRESS: at 16.41% examples, 357195 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:57,519 : INFO : EPOCH 3 - PROGRESS: at 17.28% examples, 355170 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:10:58,579 : INFO : EPOCH 3 - PROGRESS: at 18.28% examples, 354573 words/s, in_qsize 20, out_qsize 1
# 2019-04-02 16:10:59,591 : INFO : EPOCH 3 - PROGRESS: at 19.23% examples, 354486 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:00,611 : INFO : EPOCH 3 - PROGRESS: at 20.11% examples, 353947 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:01,619 : INFO : EPOCH 3 - PROGRESS: at 21.01% examples, 354127 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:02,620 : INFO : EPOCH 3 - PROGRESS: at 22.27% examples, 353880 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:03,660 : INFO : EPOCH 3 - PROGRESS: at 23.20% examples, 353875 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:04,661 : INFO : EPOCH 3 - PROGRESS: at 24.13% examples, 354369 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:05,669 : INFO : EPOCH 3 - PROGRESS: at 25.32% examples, 354800 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:06,670 : INFO : EPOCH 3 - PROGRESS: at 26.66% examples, 355042 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:07,674 : INFO : EPOCH 3 - PROGRESS: at 28.04% examples, 355481 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:08,695 : INFO : EPOCH 3 - PROGRESS: at 29.36% examples, 355901 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:09,704 : INFO : EPOCH 3 - PROGRESS: at 30.69% examples, 356469 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:10,779 : INFO : EPOCH 3 - PROGRESS: at 32.07% examples, 356192 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:11,797 : INFO : EPOCH 3 - PROGRESS: at 33.35% examples, 356106 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:11:12,840 : INFO : EPOCH 3 - PROGRESS: at 34.55% examples, 355822 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:13,901 : INFO : EPOCH 3 - PROGRESS: at 35.78% examples, 355320 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:11:14,927 : INFO : EPOCH 3 - PROGRESS: at 37.07% examples, 355393 words/s, in_qsize 20, out_qsize 2
# 2019-04-02 16:11:15,928 : INFO : EPOCH 3 - PROGRESS: at 38.44% examples, 355890 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:16,930 : INFO : EPOCH 3 - PROGRESS: at 39.70% examples, 356213 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:17,930 : INFO : EPOCH 3 - PROGRESS: at 41.03% examples, 356316 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:18,948 : INFO : EPOCH 3 - PROGRESS: at 42.41% examples, 356612 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:19,959 : INFO : EPOCH 3 - PROGRESS: at 43.73% examples, 356830 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:21,026 : INFO : EPOCH 3 - PROGRESS: at 45.12% examples, 356465 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:22,033 : INFO : EPOCH 3 - PROGRESS: at 46.38% examples, 356532 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:23,050 : INFO : EPOCH 3 - PROGRESS: at 47.60% examples, 356628 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:24,058 : INFO : EPOCH 3 - PROGRESS: at 48.87% examples, 356491 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:25,062 : INFO : EPOCH 3 - PROGRESS: at 50.14% examples, 356534 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:26,076 : INFO : EPOCH 3 - PROGRESS: at 51.34% examples, 356484 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:27,100 : INFO : EPOCH 3 - PROGRESS: at 52.55% examples, 356357 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:28,102 : INFO : EPOCH 3 - PROGRESS: at 53.62% examples, 356269 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:29,123 : INFO : EPOCH 3 - PROGRESS: at 54.82% examples, 356089 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:30,197 : INFO : EPOCH 3 - PROGRESS: at 56.18% examples, 355663 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:31,243 : INFO : EPOCH 3 - PROGRESS: at 57.44% examples, 355458 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:32,252 : INFO : EPOCH 3 - PROGRESS: at 58.73% examples, 355914 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:33,253 : INFO : EPOCH 3 - PROGRESS: at 59.92% examples, 355757 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:34,260 : INFO : EPOCH 3 - PROGRESS: at 61.15% examples, 355565 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:35,263 : INFO : EPOCH 3 - PROGRESS: at 62.37% examples, 355656 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:36,264 : INFO : EPOCH 3 - PROGRESS: at 63.76% examples, 355880 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:11:37,331 : INFO : EPOCH 3 - PROGRESS: at 65.13% examples, 355785 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:38,361 : INFO : EPOCH 3 - PROGRESS: at 66.26% examples, 355768 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:39,371 : INFO : EPOCH 3 - PROGRESS: at 67.52% examples, 355866 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:40,387 : INFO : EPOCH 3 - PROGRESS: at 68.83% examples, 356226 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:41,394 : INFO : EPOCH 3 - PROGRESS: at 69.97% examples, 356356 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:42,407 : INFO : EPOCH 3 - PROGRESS: at 71.13% examples, 356473 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:43,415 : INFO : EPOCH 3 - PROGRESS: at 72.44% examples, 356729 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:44,450 : INFO : EPOCH 3 - PROGRESS: at 73.79% examples, 356689 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:45,510 : INFO : EPOCH 3 - PROGRESS: at 74.98% examples, 356513 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:46,529 : INFO : EPOCH 3 - PROGRESS: at 76.09% examples, 356475 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:47,535 : INFO : EPOCH 3 - PROGRESS: at 77.21% examples, 356492 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:11:48,535 : INFO : EPOCH 3 - PROGRESS: at 78.38% examples, 356647 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:11:49,547 : INFO : EPOCH 3 - PROGRESS: at 79.59% examples, 356735 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:50,553 : INFO : EPOCH 3 - PROGRESS: at 80.78% examples, 356956 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:51,614 : INFO : EPOCH 3 - PROGRESS: at 82.10% examples, 357098 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:52,673 : INFO : EPOCH 3 - PROGRESS: at 83.33% examples, 356953 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:53,673 : INFO : EPOCH 3 - PROGRESS: at 84.45% examples, 356976 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:54,679 : INFO : EPOCH 3 - PROGRESS: at 85.59% examples, 356974 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:55,685 : INFO : EPOCH 3 - PROGRESS: at 86.92% examples, 357091 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:56,690 : INFO : EPOCH 3 - PROGRESS: at 88.24% examples, 357204 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:57,696 : INFO : EPOCH 3 - PROGRESS: at 89.55% examples, 357334 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:11:58,716 : INFO : EPOCH 3 - PROGRESS: at 90.86% examples, 357391 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:11:59,726 : INFO : EPOCH 3 - PROGRESS: at 92.19% examples, 357574 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:00,764 : INFO : EPOCH 3 - PROGRESS: at 93.36% examples, 357534 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:01,833 : INFO : EPOCH 3 - PROGRESS: at 94.64% examples, 357360 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:02,867 : INFO : EPOCH 3 - PROGRESS: at 95.95% examples, 357524 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:03,869 : INFO : EPOCH 3 - PROGRESS: at 97.21% examples, 357534 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:04,884 : INFO : EPOCH 3 - PROGRESS: at 98.43% examples, 357501 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:05,893 : INFO : EPOCH 3 - PROGRESS: at 99.70% examples, 357506 words/s, in_qsize 12, out_qsize 0
# 2019-04-02 16:12:05,917 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-04-02 16:12:05,953 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-04-02 16:12:05,960 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-02 16:12:05,965 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-02 16:12:05,970 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-02 16:12:05,980 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-02 16:12:05,997 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-02 16:12:06,001 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-02 16:12:06,035 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-02 16:12:06,048 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-02 16:12:06,049 : INFO : EPOCH - 3 : training on 41519358 raw words (30349239 effective words) took 84.8s, 357829 effective words/s
# 2019-04-02 16:12:07,068 : INFO : EPOCH 4 - PROGRESS: at 0.97% examples, 314461 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:08,123 : INFO : EPOCH 4 - PROGRESS: at 2.28% examples, 349136 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:09,177 : INFO : EPOCH 4 - PROGRESS: at 3.54% examples, 351448 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:10,178 : INFO : EPOCH 4 - PROGRESS: at 4.76% examples, 355516 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:11,180 : INFO : EPOCH 4 - PROGRESS: at 5.88% examples, 354659 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:12,187 : INFO : EPOCH 4 - PROGRESS: at 7.07% examples, 355204 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:13,198 : INFO : EPOCH 4 - PROGRESS: at 8.22% examples, 357206 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:12:14,202 : INFO : EPOCH 4 - PROGRESS: at 9.33% examples, 357372 words/s, in_qsize 17, out_qsize 2
# 2019-04-02 16:12:15,220 : INFO : EPOCH 4 - PROGRESS: at 10.20% examples, 356065 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:16,228 : INFO : EPOCH 4 - PROGRESS: at 11.24% examples, 357474 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:17,229 : INFO : EPOCH 4 - PROGRESS: at 12.19% examples, 359572 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:18,253 : INFO : EPOCH 4 - PROGRESS: at 13.32% examples, 359486 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:12:19,291 : INFO : EPOCH 4 - PROGRESS: at 14.36% examples, 358993 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:20,347 : INFO : EPOCH 4 - PROGRESS: at 15.47% examples, 358225 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:21,351 : INFO : EPOCH 4 - PROGRESS: at 16.48% examples, 358292 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:22,361 : INFO : EPOCH 4 - PROGRESS: at 17.44% examples, 358221 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:12:23,367 : INFO : EPOCH 4 - PROGRESS: at 18.43% examples, 358195 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:24,369 : INFO : EPOCH 4 - PROGRESS: at 19.37% examples, 358844 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:25,396 : INFO : EPOCH 4 - PROGRESS: at 20.36% examples, 359448 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:26,402 : INFO : EPOCH 4 - PROGRESS: at 21.63% examples, 360270 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:27,508 : INFO : EPOCH 4 - PROGRESS: at 22.60% examples, 359140 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:28,515 : INFO : EPOCH 4 - PROGRESS: at 23.54% examples, 359378 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:29,528 : INFO : EPOCH 4 - PROGRESS: at 24.50% examples, 359775 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:30,538 : INFO : EPOCH 4 - PROGRESS: at 25.82% examples, 359969 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:31,539 : INFO : EPOCH 4 - PROGRESS: at 27.22% examples, 360297 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:32,543 : INFO : EPOCH 4 - PROGRESS: at 28.46% examples, 359455 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:33,560 : INFO : EPOCH 4 - PROGRESS: at 29.78% examples, 359500 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:34,580 : INFO : EPOCH 4 - PROGRESS: at 31.09% examples, 359347 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:12:35,597 : INFO : EPOCH 4 - PROGRESS: at 32.40% examples, 359114 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:36,609 : INFO : EPOCH 4 - PROGRESS: at 33.62% examples, 359019 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:37,614 : INFO : EPOCH 4 - PROGRESS: at 34.79% examples, 358863 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:38,654 : INFO : EPOCH 4 - PROGRESS: at 36.05% examples, 358277 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:39,672 : INFO : EPOCH 4 - PROGRESS: at 37.30% examples, 358126 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:40,685 : INFO : EPOCH 4 - PROGRESS: at 38.65% examples, 358235 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:41,719 : INFO : EPOCH 4 - PROGRESS: at 39.92% examples, 358161 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:42,728 : INFO : EPOCH 4 - PROGRESS: at 41.30% examples, 358353 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:43,729 : INFO : EPOCH 4 - PROGRESS: at 42.55% examples, 358183 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:44,738 : INFO : EPOCH 4 - PROGRESS: at 43.94% examples, 358546 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:12:45,744 : INFO : EPOCH 4 - PROGRESS: at 45.33% examples, 358899 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:46,748 : INFO : EPOCH 4 - PROGRESS: at 46.60% examples, 359060 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:47,750 : INFO : EPOCH 4 - PROGRESS: at 47.81% examples, 359074 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:48,752 : INFO : EPOCH 4 - PROGRESS: at 49.12% examples, 359080 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:49,756 : INFO : EPOCH 4 - PROGRESS: at 50.35% examples, 359067 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:50,798 : INFO : EPOCH 4 - PROGRESS: at 51.60% examples, 358885 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:51,808 : INFO : EPOCH 4 - PROGRESS: at 52.74% examples, 358827 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:52,823 : INFO : EPOCH 4 - PROGRESS: at 53.93% examples, 358892 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:53,837 : INFO : EPOCH 4 - PROGRESS: at 55.23% examples, 358863 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:54,855 : INFO : EPOCH 4 - PROGRESS: at 56.46% examples, 358622 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:55,858 : INFO : EPOCH 4 - PROGRESS: at 57.71% examples, 358677 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:56,889 : INFO : EPOCH 4 - PROGRESS: at 59.01% examples, 358781 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:57,917 : INFO : EPOCH 4 - PROGRESS: at 60.32% examples, 359086 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:58,920 : INFO : EPOCH 4 - PROGRESS: at 61.57% examples, 359127 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:12:59,925 : INFO : EPOCH 4 - PROGRESS: at 62.87% examples, 359402 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:00,972 : INFO : EPOCH 4 - PROGRESS: at 64.33% examples, 359253 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:01,984 : INFO : EPOCH 4 - PROGRESS: at 65.55% examples, 359297 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:02,984 : INFO : EPOCH 4 - PROGRESS: at 66.72% examples, 359384 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:03,994 : INFO : EPOCH 4 - PROGRESS: at 67.98% examples, 359340 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:05,051 : INFO : EPOCH 4 - PROGRESS: at 69.19% examples, 359117 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:06,054 : INFO : EPOCH 4 - PROGRESS: at 70.30% examples, 359107 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:07,065 : INFO : EPOCH 4 - PROGRESS: at 71.55% examples, 359204 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:08,086 : INFO : EPOCH 4 - PROGRESS: at 72.81% examples, 359209 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:09,092 : INFO : EPOCH 4 - PROGRESS: at 74.11% examples, 359184 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:10,106 : INFO : EPOCH 4 - PROGRESS: at 75.30% examples, 359349 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:11,120 : INFO : EPOCH 4 - PROGRESS: at 76.42% examples, 359492 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:12,128 : INFO : EPOCH 4 - PROGRESS: at 77.59% examples, 359562 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:13,128 : INFO : EPOCH 4 - PROGRESS: at 78.80% examples, 359781 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:14,188 : INFO : EPOCH 4 - PROGRESS: at 80.00% examples, 359581 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:15,208 : INFO : EPOCH 4 - PROGRESS: at 81.18% examples, 359582 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:16,216 : INFO : EPOCH 4 - PROGRESS: at 82.46% examples, 359754 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:17,222 : INFO : EPOCH 4 - PROGRESS: at 83.69% examples, 359928 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:18,224 : INFO : EPOCH 4 - PROGRESS: at 84.76% examples, 359700 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:19,232 : INFO : EPOCH 4 - PROGRESS: at 86.00% examples, 359846 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:20,250 : INFO : EPOCH 4 - PROGRESS: at 87.33% examples, 359870 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:21,251 : INFO : EPOCH 4 - PROGRESS: at 88.69% examples, 359982 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:22,272 : INFO : EPOCH 4 - PROGRESS: at 89.94% examples, 359901 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:23,288 : INFO : EPOCH 4 - PROGRESS: at 91.22% examples, 359939 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:24,301 : INFO : EPOCH 4 - PROGRESS: at 92.48% examples, 359890 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:25,305 : INFO : EPOCH 4 - PROGRESS: at 93.72% examples, 360060 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:26,315 : INFO : EPOCH 4 - PROGRESS: at 94.97% examples, 360032 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:27,331 : INFO : EPOCH 4 - PROGRESS: at 96.23% examples, 360156 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:28,337 : INFO : EPOCH 4 - PROGRESS: at 97.51% examples, 360207 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:29,368 : INFO : EPOCH 4 - PROGRESS: at 98.87% examples, 360343 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:13:30,105 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-04-02 16:13:30,112 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-04-02 16:13:30,122 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-02 16:13:30,141 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-02 16:13:30,159 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-02 16:13:30,178 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-02 16:13:30,201 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-02 16:13:30,224 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-02 16:13:30,230 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-02 16:13:30,231 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-02 16:13:30,232 : INFO : EPOCH - 4 : training on 41519358 raw words (30348663 effective words) took 84.2s, 360540 effective words/s
# 2019-04-02 16:13:31,254 : INFO : EPOCH 5 - PROGRESS: at 0.97% examples, 313313 words/s, in_qsize 18, out_qsize 1
# ...
# 2019-04-02 16:27:03,713 : INFO : EPOCH 9 - PROGRESS: at 57.35% examples, 356695 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:04,730 : INFO : EPOCH 9 - PROGRESS: at 58.59% examples, 356941 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:05,764 : INFO : EPOCH 9 - PROGRESS: at 59.90% examples, 357091 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:06,766 : INFO : EPOCH 9 - PROGRESS: at 61.20% examples, 357322 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:07,767 : INFO : EPOCH 9 - PROGRESS: at 62.39% examples, 357270 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:08,774 : INFO : EPOCH 9 - PROGRESS: at 63.75% examples, 357286 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:09,774 : INFO : EPOCH 9 - PROGRESS: at 65.11% examples, 357461 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:10,784 : INFO : EPOCH 9 - PROGRESS: at 66.23% examples, 357424 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:11,825 : INFO : EPOCH 9 - PROGRESS: at 67.48% examples, 357306 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:12,838 : INFO : EPOCH 9 - PROGRESS: at 68.72% examples, 357405 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:13,840 : INFO : EPOCH 9 - PROGRESS: at 69.86% examples, 357309 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:14,845 : INFO : EPOCH 9 - PROGRESS: at 70.95% examples, 357217 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:15,874 : INFO : EPOCH 9 - PROGRESS: at 72.12% examples, 356886 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:16,886 : INFO : EPOCH 9 - PROGRESS: at 73.45% examples, 356863 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:17,901 : INFO : EPOCH 9 - PROGRESS: at 74.64% examples, 356716 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:18,926 : INFO : EPOCH 9 - PROGRESS: at 75.77% examples, 356643 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:19,934 : INFO : EPOCH 9 - PROGRESS: at 76.89% examples, 356652 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:20,938 : INFO : EPOCH 9 - PROGRESS: at 78.01% examples, 356766 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:21,938 : INFO : EPOCH 9 - PROGRESS: at 79.19% examples, 356703 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:22,939 : INFO : EPOCH 9 - PROGRESS: at 80.34% examples, 356648 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:23,941 : INFO : EPOCH 9 - PROGRESS: at 81.46% examples, 356574 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:24,950 : INFO : EPOCH 9 - PROGRESS: at 82.63% examples, 356283 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:25,953 : INFO : EPOCH 9 - PROGRESS: at 83.73% examples, 356013 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:26,962 : INFO : EPOCH 9 - PROGRESS: at 84.80% examples, 355808 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:28,017 : INFO : EPOCH 9 - PROGRESS: at 86.00% examples, 355592 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:29,053 : INFO : EPOCH 9 - PROGRESS: at 87.30% examples, 355494 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:30,100 : INFO : EPOCH 9 - PROGRESS: at 88.63% examples, 355346 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:31,104 : INFO : EPOCH 9 - PROGRESS: at 89.89% examples, 355409 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:32,109 : INFO : EPOCH 9 - PROGRESS: at 91.16% examples, 355468 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:33,145 : INFO : EPOCH 9 - PROGRESS: at 92.41% examples, 355288 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:34,147 : INFO : EPOCH 9 - PROGRESS: at 93.33% examples, 354533 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:35,191 : INFO : EPOCH 9 - PROGRESS: at 94.57% examples, 354335 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:36,194 : INFO : EPOCH 9 - PROGRESS: at 95.71% examples, 353975 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:37,206 : INFO : EPOCH 9 - PROGRESS: at 96.77% examples, 353473 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:38,224 : INFO : EPOCH 9 - PROGRESS: at 97.89% examples, 353032 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:39,230 : INFO : EPOCH 9 - PROGRESS: at 99.04% examples, 352687 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:39,847 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-04-02 16:27:39,871 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-04-02 16:27:39,877 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-02 16:27:39,911 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-02 16:27:39,915 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-02 16:27:39,938 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-02 16:27:39,943 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-02 16:27:39,956 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-02 16:27:39,965 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-02 16:27:39,974 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-02 16:27:39,975 : INFO : EPOCH - 9 : training on 41519358 raw words (30353131 effective words) took 86.0s, 352857 effective words/s
# 2019-04-02 16:27:40,981 : INFO : EPOCH 10 - PROGRESS: at 0.94% examples, 310940 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:41,998 : INFO : EPOCH 10 - PROGRESS: at 2.08% examples, 325797 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:43,003 : INFO : EPOCH 10 - PROGRESS: at 3.30% examples, 338952 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:44,006 : INFO : EPOCH 10 - PROGRESS: at 4.49% examples, 344226 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:45,018 : INFO : EPOCH 10 - PROGRESS: at 5.68% examples, 346586 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:46,021 : INFO : EPOCH 10 - PROGRESS: at 6.86% examples, 349696 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:47,028 : INFO : EPOCH 10 - PROGRESS: at 8.11% examples, 356844 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:48,091 : INFO : EPOCH 10 - PROGRESS: at 9.24% examples, 355247 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:49,122 : INFO : EPOCH 10 - PROGRESS: at 10.15% examples, 354457 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:50,160 : INFO : EPOCH 10 - PROGRESS: at 11.13% examples, 353619 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:51,164 : INFO : EPOCH 10 - PROGRESS: at 12.06% examples, 353989 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:52,203 : INFO : EPOCH 10 - PROGRESS: at 13.14% examples, 353948 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:53,215 : INFO : EPOCH 10 - PROGRESS: at 14.22% examples, 355176 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:54,215 : INFO : EPOCH 10 - PROGRESS: at 15.27% examples, 355564 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:55,224 : INFO : EPOCH 10 - PROGRESS: at 16.29% examples, 355232 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:56,231 : INFO : EPOCH 10 - PROGRESS: at 17.25% examples, 354982 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:57,232 : INFO : EPOCH 10 - PROGRESS: at 18.21% examples, 354812 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:58,251 : INFO : EPOCH 10 - PROGRESS: at 19.18% examples, 354943 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:27:59,264 : INFO : EPOCH 10 - PROGRESS: at 20.08% examples, 354895 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:28:00,273 : INFO : EPOCH 10 - PROGRESS: at 21.01% examples, 355725 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:01,273 : INFO : EPOCH 10 - PROGRESS: at 22.29% examples, 356074 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:02,275 : INFO : EPOCH 10 - PROGRESS: at 23.22% examples, 356250 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:03,280 : INFO : EPOCH 10 - PROGRESS: at 24.13% examples, 356269 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:04,295 : INFO : EPOCH 10 - PROGRESS: at 25.31% examples, 356515 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:05,296 : INFO : EPOCH 10 - PROGRESS: at 26.68% examples, 356975 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:28:06,318 : INFO : EPOCH 10 - PROGRESS: at 28.10% examples, 357374 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:07,370 : INFO : EPOCH 10 - PROGRESS: at 29.44% examples, 357571 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:08,378 : INFO : EPOCH 10 - PROGRESS: at 30.70% examples, 357603 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:09,404 : INFO : EPOCH 10 - PROGRESS: at 32.07% examples, 357631 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:10,405 : INFO : EPOCH 10 - PROGRESS: at 33.38% examples, 357933 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:11,451 : INFO : EPOCH 10 - PROGRESS: at 34.55% examples, 357332 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:28:12,473 : INFO : EPOCH 10 - PROGRESS: at 35.78% examples, 357219 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:13,474 : INFO : EPOCH 10 - PROGRESS: at 37.05% examples, 357293 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:14,486 : INFO : EPOCH 10 - PROGRESS: at 38.34% examples, 357200 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:15,497 : INFO : EPOCH 10 - PROGRESS: at 39.60% examples, 357208 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:16,526 : INFO : EPOCH 10 - PROGRESS: at 40.89% examples, 357005 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:17,536 : INFO : EPOCH 10 - PROGRESS: at 42.32% examples, 357359 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:18,550 : INFO : EPOCH 10 - PROGRESS: at 43.65% examples, 357719 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:19,556 : INFO : EPOCH 10 - PROGRESS: at 45.03% examples, 357907 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:20,570 : INFO : EPOCH 10 - PROGRESS: at 46.34% examples, 358034 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:21,576 : INFO : EPOCH 10 - PROGRESS: at 47.53% examples, 358010 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:22,589 : INFO : EPOCH 10 - PROGRESS: at 48.84% examples, 358134 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:23,620 : INFO : EPOCH 10 - PROGRESS: at 50.11% examples, 357899 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:24,625 : INFO : EPOCH 10 - PROGRESS: at 51.34% examples, 358067 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:25,635 : INFO : EPOCH 10 - PROGRESS: at 52.56% examples, 358172 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:26,645 : INFO : EPOCH 10 - PROGRESS: at 53.68% examples, 358136 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:27,685 : INFO : EPOCH 10 - PROGRESS: at 54.93% examples, 358092 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:28,690 : INFO : EPOCH 10 - PROGRESS: at 56.29% examples, 358255 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:28:29,693 : INFO : EPOCH 10 - PROGRESS: at 57.54% examples, 358169 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:30,701 : INFO : EPOCH 10 - PROGRESS: at 58.75% examples, 358152 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:28:31,706 : INFO : EPOCH 10 - PROGRESS: at 60.03% examples, 358349 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:32,706 : INFO : EPOCH 10 - PROGRESS: at 61.30% examples, 358556 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:33,709 : INFO : EPOCH 10 - PROGRESS: at 62.62% examples, 358990 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:34,731 : INFO : EPOCH 10 - PROGRESS: at 64.05% examples, 359013 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:35,760 : INFO : EPOCH 10 - PROGRESS: at 65.35% examples, 359106 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:36,805 : INFO : EPOCH 10 - PROGRESS: at 66.53% examples, 358928 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:37,813 : INFO : EPOCH 10 - PROGRESS: at 67.76% examples, 358882 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:38,825 : INFO : EPOCH 10 - PROGRESS: at 69.00% examples, 358952 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:39,843 : INFO : EPOCH 10 - PROGRESS: at 70.11% examples, 358970 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:40,850 : INFO : EPOCH 10 - PROGRESS: at 71.29% examples, 358971 words/s, in_qsize 18, out_qsize 1
# 2019-04-02 16:28:41,852 : INFO : EPOCH 10 - PROGRESS: at 72.53% examples, 358996 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:42,852 : INFO : EPOCH 10 - PROGRESS: at 73.90% examples, 359111 words/s, in_qsize 17, out_qsize 2
# 2019-04-02 16:28:43,858 : INFO : EPOCH 10 - PROGRESS: at 75.07% examples, 359194 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:44,863 : INFO : EPOCH 10 - PROGRESS: at 76.15% examples, 359082 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:45,867 : INFO : EPOCH 10 - PROGRESS: at 77.33% examples, 359283 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:46,895 : INFO : EPOCH 10 - PROGRESS: at 78.52% examples, 359359 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:47,925 : INFO : EPOCH 10 - PROGRESS: at 79.74% examples, 359316 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:48,946 : INFO : EPOCH 10 - PROGRESS: at 80.90% examples, 359318 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:49,962 : INFO : EPOCH 10 - PROGRESS: at 82.13% examples, 359342 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:51,015 : INFO : EPOCH 10 - PROGRESS: at 83.37% examples, 359197 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:52,023 : INFO : EPOCH 10 - PROGRESS: at 84.56% examples, 359555 words/s, in_qsize 20, out_qsize 0
# 2019-04-02 16:28:53,049 : INFO : EPOCH 10 - PROGRESS: at 85.80% examples, 359613 words/s, in_qsize 19, out_qsize 1
# 2019-04-02 16:28:54,070 : INFO : EPOCH 10 - PROGRESS: at 87.09% examples, 359434 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:55,079 : INFO : EPOCH 10 - PROGRESS: at 88.35% examples, 359307 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:56,084 : INFO : EPOCH 10 - PROGRESS: at 89.63% examples, 359315 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:57,087 : INFO : EPOCH 10 - PROGRESS: at 90.93% examples, 359422 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:58,105 : INFO : EPOCH 10 - PROGRESS: at 92.21% examples, 359352 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:28:59,131 : INFO : EPOCH 10 - PROGRESS: at 93.38% examples, 359336 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:29:00,135 : INFO : EPOCH 10 - PROGRESS: at 94.64% examples, 359348 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:29:01,146 : INFO : EPOCH 10 - PROGRESS: at 95.91% examples, 359411 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:29:02,155 : INFO : EPOCH 10 - PROGRESS: at 97.15% examples, 359365 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:29:03,163 : INFO : EPOCH 10 - PROGRESS: at 98.37% examples, 359335 words/s, in_qsize 19, out_qsize 0
# 2019-04-02 16:29:04,171 : INFO : EPOCH 10 - PROGRESS: at 99.65% examples, 359322 words/s, in_qsize 14, out_qsize 0
# 2019-04-02 16:29:04,244 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-04-02 16:29:04,252 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-04-02 16:29:04,258 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-02 16:29:04,316 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-02 16:29:04,323 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-02 16:29:04,329 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-02 16:29:04,335 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-02 16:29:04,358 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-02 16:29:04,364 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-02 16:29:04,369 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-02 16:29:04,369 : INFO : EPOCH - 10 : training on 41519358 raw words (30348589 effective words) took 84.4s, 359630 effective words/s
# 2019-04-02 16:29:04,370 : INFO : training on a 415193580 raw words (303503457 effective words) took 847.1s, 358300 effective words/s
# (303503457, 415193580)

# %% [markdown]
# ## Now, let's look at some output
# This first example shows a simple case of looking up words similar to the word `dirty`. All we need to do here is to call the `most_similar` function and provide the word `dirty` as the positive example. This returns the top 10 similar words using cosine similarity (which is exactly what is sounds like):

# %%
w1 = "dirty"
model.wv.most_similar (positive=w1)
# Out:
# [('filthy', 0.8858400583267212),
#  ('unclean', 0.8308728337287903),
#  ('smelly', 0.8303340077400208),
#  ('stained', 0.8210866451263428),
#  ('dingy', 0.8048659563064575),
#  ('dusty', 0.7949382066726685),
#  ('grubby', 0.7872313857078552),
#  ('disgusting', 0.7742273211479187),
#  ('gross', 0.7593685388565063),
#  ('moldy', 0.7495971322059631)]

# %% [markdown]
# Let's look at similarity for `polite`, `france` and `shocked`.

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('courteous', 0.9150029420852661),
#  ('professional', 0.8537306785583496),
#  ('attentive', 0.8418415188789368),
#  ('friendly', 0.8116524815559387),
#  ('helpful', 0.8044909238815308),
#  ('efficient', 0.8029367327690125)]

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('germany', 0.6528472304344177),
#  ('england', 0.6416741013526917),
#  ('europe', 0.6261036992073059),
#  ('paris', 0.620964527130127),
#  ('gaulle', 0.5984228849411011),
#  ('spain', 0.5930178761482239)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('horrified', 0.7343902587890625),
#  ('surprised', 0.7182973027229309),
#  ('amazed', 0.7052606344223022),
#  ('dismayed', 0.7013192772865295),
#  ('appalled', 0.6982929706573486),
#  ('astonished', 0.6873292922973633)]

# %% [markdown]
# We can even specify several positive examples to get things that are related in the provided context and provide negative examples to say what should not be considered as related. In the example below we are asking for all items that *relate to bed, sheet, and pillow* only:

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet','pillow']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# [('duvet', 0.7795587182044983),
#  ('sheets', 0.7652061581611633),
#  ('comforter', 0.7430680990219116),
#  ('pillows', 0.7363089323043823),
#  ('blanket', 0.7252493500709534),
#  ('quilt', 0.715475857257843),
#  ('feather', 0.7088570594787598),
#  ('mattress', 0.7060394287109375),
#  ('undersheet', 0.6786792278289795),
#  ('matress', 0.6667504906654358)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# You can even use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
# similarity between two different words
model.wv.similarity(w1="dirty",w2="couch")
# Out:
# 0.30352983

# %%
# similarity between two different but similar contextually words
model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# 0.8303339

# %%
# similarity between two negatively correlated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# 0.33860257

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty",w2="dirty")
# Out:
# 1.0

# %%
# similarity between two opposite verbs
model.wv.similarity(w1='break', w2='fix')
# Out:
# 0.15821667

# %%
# similarity between two opposite descriptors
model.wv.similarity(w1='broke', w2='fixed')
# Out:
# 0.5597079

# %% [markdown]
# Under the hood, the above three snippets computes the cosine similarity between the two specified words using word vectors of each. From the scores, it makes sense that `dirty` is highly similar to `smelly` but `dirty` is dissimilar to `clean`. If you do a similarity between two identical words, the score will be 1.0 as the range of the cosine similarity score will always be between [0.0-1.0]. You can read more about cosine similarity scoring [here](https://en.wikipedia.org/wiki/Cosine_similarity).

# %% [markdown]
# The reason to use cosine similarity rather than Euclidean distance, for example, is that we don't really care about the overally length of the vectors but just the angles between them as this states how they relate in similarity.

# %% [markdown]
# ### Find the odd one out
# You can even use Word2Vec to find odd items given a list of items.

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/keyedvectors.py:858: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","duvet","shower"])
# Out:
# 'shower'

# %% [markdown]
# ## Understanding some of the parameters
# To train the model earlier, we had to set some parameters. Now, let's try to understand what some of them mean. For reference, this is the command that we used to train the model.
#
# ```
# model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
# ```
#
# ### `size`
# The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.
#
# ### `window`
# The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.
#
# ### `min_count`
# Minimium frequency count of words. The model would ignore words that do not statisfy the `min_count`. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.
#
# ### `workers`
# How many threads to use behind the scenes?
#
# ### `sg`
# Set sg to 1 to use the skip gram model and set it to 0 to use CBOW. By default, sg is set to 0

# %% [markdown]
# ## When should you use Word2Vec?
#
# There are many application scenarios for Word2Vec. Imagine if you need to build a sentiment lexicon. Training a Word2Vec model on large amounts of user reviews helps you achieve that. You have a lexicon for not just sentiment, but for most words in the vocabulary.
#
# Beyond, raw unstructured text data, you could also use Word2Vec for more structured data. For example, if you had tags for a million stackoverflow questions and answers, you could find tags that are related to a given tag and recommend the related ones for exploration. You can do this by treating each set of co-occuring tags as a "sentence" and train a Word2Vec model on this data. Granted, you still need a large number of examples to make it work.
